# %% [markdown]
# # Assignment Set 3 Solutions - Conditional filtering and sorting

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Q1. Which manufacturer, model and type has the highest price in the Cars93 dataset.

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
# Solution
df.loc[df.Price == np.max(df.Price), ['Manufacturer', 'Model', 'Type']]
# Out:
#      Manufacturer Model     Type
# 58  Mercedes-Benz  300E  Midsize

# %% [markdown]
# ### Q2. Create a new column in Cars93 dataset which represents weight to highway mileage ration (Weight and MPG.highway columns).

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
# Solution 1
df['weight_mileage'] = df['Weight']/df['MPG.highway']
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Length  Wheelbase  Width  \
# 0         31.0                None      Front  ...  177.0      102.0   68.0
# 1         25.0  Driver & Passenger      Front  ...  195.0      115.0   71.0
# 2         26.0         Driver only      Front  ...  180.0      102.0   67.0
# 3         26.0  Driver & Passenger        NaN  ...  193.0      106.0    NaN
# 4         30.0                 NaN       Rear  ...  186.0      109.0   69.0
#
# ...

# %%
# Solution 2
df.loc[:, 'weight_mileage'] = df.loc[:, 'Weight']/df.loc[:, 'MPG.highway']
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Length  Wheelbase  Width  \
# 0         31.0                None      Front  ...  177.0      102.0   68.0
# 1         25.0  Driver & Passenger      Front  ...  195.0      115.0   71.0
# 2         26.0         Driver only      Front  ...  180.0      102.0   67.0
# 3         26.0  Driver & Passenger        NaN  ...  193.0      106.0    NaN
# 4         30.0                 NaN       Rear  ...  186.0      109.0   69.0
#
# ...

# %% [markdown]
# ### Q3. Print the 10th value in Price column in the Cars93 dataset and replace it with 50

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
# Solution 1
print(df['Price'][10]) # print 10th value

df['Price'][10] = 50 # replace 10th value

print(df['Price'][10]) # print 10th value
# Out:
# 40.1
# 50.0
# <ipython-input-19-9627e22ab2a3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'][10] = 50 # replace 10th value

# %%
# Solution 2

df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
print(df.at[10, 'Price']) # print 10th value

df.at[10, 'Price'] = 50 # replace 10th value

print(df.at[10, 'Price']) # print 10th value
# Out:
# 40.1
# 50.0

# %%
# Solution 3

df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
print(df.loc[10, 'Price']) # print 10th value

df.loc[10, 'Price'] = 50 # replace 10th value

print(df.loc[10, 'Price']) # print 10th value
# Out:
# 40.1
# 50.0

# %% [markdown]
# ### Q4. Filter the 'Manufacturer', 'Model' and 'Type' for every 20th row starting from 1st (row 0) in Cars93 dataset

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
# Solution
df.iloc[::20, :][['Manufacturer', 'Model', 'Type']]
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %% [markdown]
# ### Q5. Filter out the car models which has price greater than 40 in the Cars93 dataset.

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
# Solution
df.loc[df['Price'] > 40, :]
# Out:
#      Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 10       Cadillac  Seville  Midsize       37.5   40.1       42.7      16.0
# 47       Infiniti      Q45  Midsize       45.4   47.9        NaN      17.0
# 58  Mercedes-Benz     300E  Midsize       43.8   61.9       80.0      19.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 10         25.0  Driver & Passenger      Front  ...        5.0   204.0
# 47         22.0                 NaN       Rear  ...        5.0   200.0
# 58         25.0  Driver & Passenger       Rear  ...        5.0     NaN
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 10      111.0   74.0         44.0           31.0           NaN  3935.0
# 47      113.0   72.0         42.0           29.0          15.0  4000.0
# 58      110.0   69.0         37.0            NaN          15.0  3525.0
#
#      Origin                Make
# 10      USA    Cadillac Seville
# ...

# %% [markdown]
# ### Q6. Filter out the car models which has price greater than 40  and less than 60 in the Cars93 dataset.

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
# Solution

filter1 = df['Price'] > 40
filter2 = (df['Price'] < 60)

df.loc[(filter1 & filter2), :]
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 10     Cadillac  Seville  Midsize       37.5   40.1       42.7      16.0
# 47     Infiniti      Q45  Midsize       45.4   47.9        NaN      17.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 10         25.0  Driver & Passenger      Front  ...        5.0   204.0
# 47         22.0                 NaN       Rear  ...        5.0   200.0
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 10      111.0   74.0         44.0           31.0           NaN  3935.0
# 47      113.0   72.0         42.0           29.0          15.0  4000.0
#
#      Origin              Make
# 10      USA  Cadillac Seville
# 47  non-USA      Infiniti Q45
#
# [2 rows x 27 columns]

# %% [markdown]
# ### Q7. Find out which all types of vehicle are made by each manufacturer in the Cars93 dataset.

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
# Solution
df[['Manufacturer', 'Type']].drop_duplicates()
# Out:
#    Manufacturer     Type
# 0         Acura    Small
# 1           NaN  Midsize
# 2          Audi  Compact
# 3          Audi  Midsize
# 4           BMW  Midsize
# ..          ...      ...
# 87   Volkswagen    Small
# 88   Volkswagen      Van
# 89   Volkswagen  Compact
# 90   Volkswagen   Sporty
# 91        Volvo  Compact
#
# [80 rows x 2 columns]

# %% [markdown]
# ### Q8. Sort `Manufacturer` in alphabetical order but `MPG.highway` in descending order in Cars93 dataset

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
# Solution
df.sort_values(by=['Manufacturer', 'MPG.highway'], ascending=[True, False])
# Out:
#    Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura   Integra    Small       12.9   15.9       18.8      25.0
# 2          Audi        90  Compact       25.9   29.1       32.3      20.0
# 3          Audi       100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW      535i  Midsize        NaN   30.0        NaN      22.0
# 5         Buick   Century  Midsize       14.2   15.7       17.3      22.0
# ..          ...       ...      ...        ...    ...        ...       ...
# 91        Volvo       240  Compact       21.8   22.7       23.5      21.0
# 19          NaN  Concorde    Large       18.4   18.4       18.4      20.0
# 92          NaN       850  Midsize       24.8   26.7       28.5      20.0
# 1           NaN    Legend  Midsize       29.2   33.9       38.7      18.0
# 49          NaN     SC300  Midsize       34.7   35.2       35.6      18.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...
